# %% [markdown]
# Homework4

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu4.jpg')
rows,cols,ch = img.shape
plt.figure(figsize=(20, 10))


pts1 = np.float32([[237,269],[570,235],[566,496],[235,462]])
pts2 = np.float32([[200,200],[500,200],[500,400],[200,400]])

M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1024,768))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('fantasy.jpg')

b,g,r = cv2.split(img)
img = cv2.merge((r,g,b))

rows,cols,ch = img.shape
plt.figure(figsize=(20, 10))


pts1 = np.float32([[380,30],[700,230],[720,410],[370,330]])
pts2 = np.float32([[0,100],[800,100],[800,500],[0,500]])

M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(800,530))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
